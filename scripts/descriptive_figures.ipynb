# %%
import pandas as pd
import numpy as np
import altair as alt
import matplotlib as plt
import altair_saver
from altair import datum

# %%
metadata = pd.read_csv("../monkeypox-build/data/nextstrain__metadata_3000.tsv", sep = "\t")

# %%
meta_b = metadata[metadata.lineage.str.contains('^B.*')==True]
meta_b = meta_b[meta_b['date'].notna()]
meta_b["year_month"] = meta_b['date'].str.rsplit("-", 1).str[-0].tolist()
meta_b = meta_b[meta_b.year_month.str.contains('XX*')==False]
meta_b
# Out:
#                                                 strain        date  \
# 0                                                 4061  2022-05-20
# 1                                                 8887  2022-06-06
# 2                                              9000231  2022-07-25
# 3                                              9000289  2022-08-01
# 4                                              9000327  2022-08-17
# ...                                                ...         ...
# 3008             hMPX/Human/USA/CA-LACPHL-MA00053/2022  2022-07-25
# 3009              MPX/Human/USA/CA-LACPHL-MA00237/2022  2022-07-20
# 3010              MPX/Human/USA/CA-LACPHL-MA00144/2022  2022-08-30
# 3011  Monkeypox virus/Human/USA/CA-LACPHL-MA00379/2022  2022-10-12
# 3012             MPXV/Human/USA/CA-LACPHL-MA00303/2022  2022-09-29
#
#               host recency date_submitted lineage         region  \
# 0     Homo sapiens   Older     2022-06-24     B.1         Europe
# 1     Homo sapiens   Older     2022-06-24     B.1         Europe
# 2     Homo sapiens   Older     2022-09-12   B.1.2         Europe
# 3     Homo sapiens   Older     2022-09-12   B.1.5         Europe
# 4     Homo sapiens   Older     2022-09-12   B.1.2         Europe
# ...            ...     ...            ...     ...            ...
# 3008  Homo sapiens   Older     2022-09-15   B.1.2  North America
# 3009  Homo sapiens   Older     2022-10-27   B.1.2  North America
# 3010  Homo sapiens   Older     2022-09-27   B.1.2  North America
# 3011  Homo sapiens   Older     2023-01-26   B.1.2  North America
# 3012  Homo sapiens   Older     2022-11-24   B.1.2  North America
#
#      clade_membership         country  \
# 0                 IIb           Spain
# 1                 IIb           Spain
# 2                 IIb  United Kingdom
# 3                 IIb  United Kingdom
# 4                 IIb  United Kingdom
# ...               ...             ...
# 3008              IIb             USA
# 3009              IIb             USA
# 3010              IIb             USA
# 3011              IIb             USA
# 3012              IIb             USA
#
#                                                  author accession  \
# 0     de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...  ON838940
# 1     de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...  ON838939
# 2     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413713
# 3     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413714
# 4     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413715
# ...                                                 ...       ...
# 3008                          Hemarajata,P., Green,N.M.  OP440544
# 3009          Hemarajata,P., Green,N.M., Garrigues,J.M.  OP722496
# 3010          Hemarajata,P., Green,N.M., Garrigues,J.M.  OP539929
# 3011          Hemarajata,P., Green,N.M., Garrigues,J.M.  OQ330985
# 3012          Hemarajata,P., Green,N.M., Garrigues,J.M.  OP890537
#
#       GA_CT_fraction  dinuc_context_fraction year_month
# 0                NaN                     NaN    2022-05
# 1                NaN                     NaN    2022-06
# 2                NaN                     NaN    2022-07
# 3                NaN                     NaN    2022-08
# 4                NaN                     NaN    2022-08
# ...              ...                     ...        ...
# 3008             NaN                     NaN    2022-07
# 3009             NaN                     NaN    2022-07
# 3010             NaN                     NaN    2022-08
# 3011             1.0                     1.0    2022-10
# 3012             1.0                     1.0    2022-09
#
# [3012 rows x 14 columns]

# %%
region = {'Canada':'North America',
          'USA':'North America',
         'Finland':'Northern Europe',
           'Austria': 'Western Europe',
        'Germany':'Western Europe', 
        'Switzerland':'Western Europe',
         'United Kingdom':'Western Europe',
        'France':'Western Europe',
        'Belgium':'Western Europe',
        'Netherlands':'Western Europe',
        'Slovakia':'Central Europe',
        'Slovenia':'Central Europe',
        'Italy':'Southern Europe',
        'Portugal':'Southern Europe',
        'Spain':'Southern Europe',
         'Colombia':'South America',
          
        'Peru':'South America'}

country_list = meta_b.country.value_counts().loc[lambda x: x>5].index.tolist()
meta_b = meta_b[meta_b.country.isin(country_list)]
meta_b = meta_b[meta_b.country != "Brazil"]
meta_b = meta_b[meta_b.country != "Netherlands"]
meta_b["region"] = np.nan
meta_b.region = meta_b.country.map(region)
#meta_b = meta_b.dropna()

meta_b
# Out:
#                                                 strain        date  \
# 0                                                 4061  2022-05-20
# 1                                                 8887  2022-06-06
# 2                                              9000231  2022-07-25
# 3                                              9000289  2022-08-01
# 4                                              9000327  2022-08-17
# ...                                                ...         ...
# 3008             hMPX/Human/USA/CA-LACPHL-MA00053/2022  2022-07-25
# 3009              MPX/Human/USA/CA-LACPHL-MA00237/2022  2022-07-20
# 3010              MPX/Human/USA/CA-LACPHL-MA00144/2022  2022-08-30
# 3011  Monkeypox virus/Human/USA/CA-LACPHL-MA00379/2022  2022-10-12
# 3012             MPXV/Human/USA/CA-LACPHL-MA00303/2022  2022-09-29
#
#               host recency date_submitted lineage           region  \
# 0     Homo sapiens   Older     2022-06-24     B.1  Southern Europe
# 1     Homo sapiens   Older     2022-06-24     B.1  Southern Europe
# 2     Homo sapiens   Older     2022-09-12   B.1.2   Western Europe
# 3     Homo sapiens   Older     2022-09-12   B.1.5   Western Europe
# 4     Homo sapiens   Older     2022-09-12   B.1.2   Western Europe
# ...            ...     ...            ...     ...              ...
# 3008  Homo sapiens   Older     2022-09-15   B.1.2    North America
# 3009  Homo sapiens   Older     2022-10-27   B.1.2    North America
# 3010  Homo sapiens   Older     2022-09-27   B.1.2    North America
# 3011  Homo sapiens   Older     2023-01-26   B.1.2    North America
# 3012  Homo sapiens   Older     2022-11-24   B.1.2    North America
#
#      clade_membership         country  \
# 0                 IIb           Spain
# 1                 IIb           Spain
# 2                 IIb  United Kingdom
# 3                 IIb  United Kingdom
# 4                 IIb  United Kingdom
# ...               ...             ...
# 3008              IIb             USA
# 3009              IIb             USA
# 3010              IIb             USA
# 3011              IIb             USA
# 3012              IIb             USA
#
#                                                  author accession  \
# 0     de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...  ON838940
# 1     de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...  ON838939
# 2     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413713
# 3     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413714
# 4     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413715
# ...                                                 ...       ...
# 3008                          Hemarajata,P., Green,N.M.  OP440544
# 3009          Hemarajata,P., Green,N.M., Garrigues,J.M.  OP722496
# 3010          Hemarajata,P., Green,N.M., Garrigues,J.M.  OP539929
# 3011          Hemarajata,P., Green,N.M., Garrigues,J.M.  OQ330985
# 3012          Hemarajata,P., Green,N.M., Garrigues,J.M.  OP890537
#
#       GA_CT_fraction  dinuc_context_fraction year_month
# 0                NaN                     NaN    2022-05
# 1                NaN                     NaN    2022-06
# 2                NaN                     NaN    2022-07
# 3                NaN                     NaN    2022-08
# 4                NaN                     NaN    2022-08
# ...              ...                     ...        ...
# 3008             NaN                     NaN    2022-07
# 3009             NaN                     NaN    2022-07
# 3010             NaN                     NaN    2022-08
# 3011             1.0                     1.0    2022-10
# 3012             1.0                     1.0    2022-09
#
# [3012 rows x 14 columns]

# %%
# Out:
# Isidro,J., Borges,V., Pinto,M., Sobral,D., Santos,J., Nunes,A., Mixao,V., Ferreira,R., Santos,D., Duarte,S., Vieira,L., Borrego,M.J., Nuncio,S., Lopes de Carvalho,I., Pelerito,A., Cordeiro,R., Gomes,J.P.                                                   474
# Brinkmann,A., Kohl,C., Pape,K., Schrick,L., Michel,J., Schaade,L., Nitsche,A.                                                                                                                                                                                 283
# Hemarajata,P., Green,N.M., Garrigues,J.M.                                                                                                                                                                                                                     267
# Groves,N., Osman,K.L., Lewandowski,K.S., Carter,D.P., Pullan,S.T., Myers,R., Vipond,R., Chand,M.                                                                                                                                                              254
# Sereewit,J., Xie,H., Roychoudhury,P., Greninger,A.L.                                                                                                                                                                                                          242
#                                                                                                                                                                                                                                                              ...
# Silva,I., Jimenez,V., Hurtado,V., Barcena,L.                                                                                                                                                                                                                    1
# Gigante,C.M., Acheampong,E., Zhao,H., Batra,D., Hetrick,E.E., Howard,D.T., Kovar,L., Seabolt,M.H., Knipe,K., Burroughs,S., Lee,J., Wilkins,K., McCollum,A., Hutson,C., Davidson,W., Rao,A., McDermott,D., Li,Y.                                                 1
# Burton,J., Easterbrook,L., Drinkwater,E., Groves,N., Osman,K.L., Lewandowski,K.S., Carter,D., Pullan,S.T., Myers,R., Vipond,R., Chand,M.                                                                                                                        1
# Gigante,C.M., Kubin,G., Zhao,H., Batra,D., Hetrick,E.E., Howard,D.T., Kovar,L., Seabolt,M.H., Weigand,M.R., Burroughs,M.S., Lee,J., Wilkins,K., McCollum,A., Hutson,C., Davidson,W., Rao,A., White,S.L., Li,Y.                                                  1
# Gigante,C., Francis,D., Zhao,H., Batra,D., Hetrick,E., Howard,D., Kovar,L., Seabolt,M., Morrison,S., Desch,M., Knipe,K., Weigand,M., Sheth,M., Burgin,A., Burroughs,M., Lee,J., Wilkins,K., McCollum,A., Hutson,C., Davidson,W., Rao,A., Escobar,J., Li,Y.      1
# Name: author, Length: 218, dtype: int64

# %%
meta_b.date = pd.to_datetime(meta_b.date)
meta_b['year_week'] = meta_b['date'].dt.year.astype(str) + '-' + meta_b['date'].dt.week.astype(str).str.zfill(2)
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_7494/3011260860.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   meta_b['year_week'] = meta_b['date'].dt.year.astype(str) + '-' + meta_b['date'].dt.week.astype(str).str.zfill(2)

# %%
meta_b[meta_b.year_month == "2022-03"]
# Out:
#                  strain       date          host recency date_submitted  \
# 452  MPX_96X1Vd_9000217 2022-03-28  Homo sapiens   Older     2022-09-12
# 466  MPX_96X1Vd_9000216 2022-03-28  Homo sapiens   Older     2022-09-12
# 519  MPX_96X1Vd_9000218 2022-03-28  Homo sapiens   Older     2022-09-12
#
#     lineage          region clade_membership         country  \
# 452     B.1  Western Europe              IIb  United Kingdom
# 466     B.1  Western Europe              IIb  United Kingdom
# 519     B.1  Western Europe              IIb  United Kingdom
#
#                                                 author accession  \
# 452  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP415195
# 466  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP415194
# 519  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP415196
#
#      GA_CT_fraction  dinuc_context_fraction year_month year_week
# 452             NaN                     NaN    2022-03   2022-13
# 466             NaN                     NaN    2022-03   2022-13
# 519             NaN                     NaN    2022-03   2022-13

# %%
country_count = meta_b.groupby(["year_month"])["country"].value_counts().reset_index(name="count")
region_count = meta_b.groupby(["year_month"])["region"].value_counts().reset_index(name="count")

# %%
         # blues
colors = {"Canada":"#133253",
          "USA":"#2664A5",
        
          
          # greens
          "United Kingdom":"#1C3828",
          "Germany":"#356D4C",
          "Switzerland":"#81A48F",
          "Austria":"#B3C8BC",
          "France":"#CCDAD2",

          "Belgium":"#438B62",

          
          # yellows
          "Slovakia":"#D0A854",
          "Slovenia":"#EEC060",

          
          # oranges
          "Italy":"#D07954",
          "Portugal":"#EEA160",
          "Spain":"#F4C49C",
          
          # purples
          "Colombia":"#2D1E45",
          "Peru":"#695B82",
          #"ancestor":'grey'


         }

#uncertainty_color = "#B9B9B9"

# %%
colors = {
    "Austria": "#B3C8BC",
    "Belgium": "#438B62",
    "Canada": "#133253",
    "Colombia": "#2D1E45",
    "France": "#CCDAD2",
    "Germany": "#356D4C",
    "Italy": "#D07954",
    "Peru": "#695B82",
    "Portugal": "#EEA160",
    "Slovakia": "#D0A854",
    "Slovenia": "#EEC060",
    "Spain": "#F4C49C",
    "Switzerland": "#81A48F",
    "United Kingdom": "#1C3828",
    "USA": "#2664A5"
}

# %%
colors = {
    
                    # yellows
          "Slovakia":"#D0A854",
          "Slovenia":"#EEC060",
    
          "Canada":"#133253",
          "USA":"#2664A5",
    
          # purples
          "Colombia":"#2D1E45",
          "Peru":"#695B82",
          #"ancestor":'grey',
          # oranges
          "Italy":"#D07954",
          "Portugal":"#EEA160",
          "Spain":"#F4C49C",
          # greens
          "United Kingdom":"#1C3828",
          "Germany":"#356D4C",
          "Switzerland":"#81A48F",
          "Austria":"#B3C8BC",
          "France":"#CCDAD2",
          "Belgium":"#438B62",
          #"Netherlands":"#60B684",



          # reds
          #"Finland":"#C5656E"
         }

# %%
country_count['order'] = country_count['country'].replace(
    {val: i for i, val in enumerate(colors.keys())}
)

#range_ = ["#5E1D9D","#492AB5","#4042C7","#3E5DD0","#4377CD","#4A8CC2","#549DB2","#60AA9E","#6EB389","#80B974","#92BC63","#A6BE55","#B9BC4A","#CBB742","#D9AD3D","#E29D39","#E68634","#E56A2F","#E04929","#DB2823"]
monthly_seqs_country = alt.Chart(country_count).mark_bar(size = 70).encode(
    alt.X("year_month:T",axis=alt.Axis(title="", grid=False, format="%B %Y")),
    alt.Y("count",axis=alt.Axis( grid=False, title = "Monthly Number of Mpox Genomes", offset = 30)), 
    alt.Color("country:N", scale=alt.Scale(domain=list(colors.keys()), range=list(colors.values())), legend=alt.Legend(title = "Country", orient = "right",offset = -165, labelFontSize = 20, titleFontSize = 20, symbolSize = 110)), 
    alt.Order("order", sort = "descending")).properties(
    width = 800,
    height = 500
)
monthly_seqs_country
# Out:
# alt.Chart(...)

# %%
domain = ['Central Europe', 'North America', 'South America' ,"Southern Europe", "Western Europe"]
range_ = ['#EEC060', '#2664A5', '#A76BB1', "#EEA160", "#356D4C"]
monthly_seqs_region = alt.Chart(region_count).mark_bar(size = 70).encode(
    alt.X("year_month:T",axis=alt.Axis(title="", grid=False, format="%B %Y")),
    alt.Y("count",axis=alt.Axis( grid=False, title = "Monthly Number of Mpox Genomes", offset = 30)), 
    alt.Color("region:N", scale=alt.Scale(domain=domain, range=range_), legend=alt.Legend(title = "Region", orient = "right",offset = -165, labelFontSize = 20, titleFontSize = 20, symbolSize = 110))).properties(
    width = 800,
    height = 500
)
monthly_seqs_region
# Out:
# alt.Chart(...)

# %%
# Getting data
raw_cases = pd.read_csv("../case-rt-analysis/data/monkeypox-cases-counts.tsv", sep="\t")
raw_cases.location.value_counts()
# Out:
# World             270
# United Kingdom    265
# Portugal          255
# Spain             254
# Belgium           253
# France            253
# Italy             253
# Germany           252
# Switzerland       251
# Austria           249
# Slovenia          248
# Canada            238
# United States     238
# Colombia          216
# Peru              213
# Slovakia          204
# Name: location, dtype: int64

# %%
raw_cases= raw_cases[raw_cases.location != "World"]
raw_cases.location[raw_cases.location == "United States"] = "USA"
raw_cases[(raw_cases.location == "United Kingdom") & (raw_cases.date > "2022-10-01")]
raw_cases.set_index('date', inplace=True)
raw_cases.index = pd.to_datetime(raw_cases.index)
raw_cases["region"] = np.nan
raw_cases.region = raw_cases.location.map(region)
weekly_prevalence = raw_cases.groupby(["location"]).resample('1W').sum().reset_index()
weekly_count_region = raw_cases.groupby(["region"]).resample('1W').sum().reset_index()

#month_prevalence["year-month"]= pd.to_datetime(month_prevalence['date']).dt.to_period('M')
weekly_prevalence
# Out:
#            location       date  cases
# 0           Austria 2022-05-29    1.0
# 1           Austria 2022-06-05    0.0
# 2           Austria 2022-06-12    0.0
# 3           Austria 2022-06-19   10.0
# 4           Austria 2022-06-26    9.0
# ..              ...        ...    ...
# 528  United Kingdom 2023-01-01    0.0
# 529  United Kingdom 2023-01-08    0.0
# 530  United Kingdom 2023-01-15    0.0
# 531  United Kingdom 2023-01-22    5.0
# 532  United Kingdom 2023-01-29    0.0
#
# [533 rows x 3 columns]

# %%
weekly_prevalence['order'] = weekly_prevalence['location'].replace(
    {val: i for i, val in enumerate(colors.keys())}
)

weekly_cases_country = alt.Chart(weekly_prevalence).mark_bar(interpolate = "monotone", size =20).encode(
    alt.X("date:T", axis=alt.Axis( title="", grid=False, format="%B %Y")),
    alt.Y("cases", axis=alt.Axis( grid=False, title= "Weekly Mpox Cases")), 
    alt.Color("location:N", title = "country",  scale=alt.Scale(domain=list(colors.keys()), range=list(colors.values())), legend=alt.Legend(title = "Country", orient = "right",offset = -165, labelFontSize = 20, titleFontSize = 20, symbolSize = 110)), 
    alt.Order("order", sort = "descending")).properties(
    width = 800,
    height = 500
)
weekly_cases_country
# Out:
# alt.Chart(...)

# %%
domain = ['Central Europe', 'North America', 'South America' ,"Southern Europe", "Western Europe"]
range_ = ['#EEC060', '#2664A5', '#A76BB1', "#EEA160", "#356D4C"]
weekly_cases_region = alt.Chart(weekly_count_region).mark_bar(interpolate = "monotone", size =20).encode(
    alt.X("date:T", axis=alt.Axis( title="", grid=False, format="%B %Y")),
    alt.Y("cases", axis=alt.Axis( grid=False, title = "Weekly Mpox Cases")), 
    alt.Color("region:N", scale=alt.Scale(domain = domain, range=range_), legend=alt.Legend(title = "Region", orient = "right",offset = -165, labelFontSize = 20, titleFontSize = 20, symbolSize = 110))).properties(
    width = 800,
    height = 500
)
weekly_cases_region
# Out:
# alt.Chart(...)

# %%
# Add labels to each chart
weekly_cases_country = weekly_cases_country.properties(title='A')
monthly_seqs_country = monthly_seqs_country.properties(title='C')
weekly_cases_region = weekly_cases_region.properties(title='B')
monthly_seqs_region = monthly_seqs_region.properties(title='D')

# Concatenate labeled charts A and B horizontally
chart_ab_labeled = alt.hconcat(weekly_cases_country, weekly_cases_region, spacing=50).resolve_scale(x = "shared", y='independent', color = "independent" )

# Concatenate labeled charts C and D horizontally
chart_cd_labeled = alt.hconcat(monthly_seqs_country, monthly_seqs_region, spacing=50).resolve_scale(x = "shared", y='independent', color = "independent")

# Concatenate labeled charts AB and CD vertically
chart_abcd_labeled = alt.vconcat(chart_ab_labeled, chart_cd_labeled, spacing=50).resolve_scale(x='shared', color ='independent')

chart_abcd_labeled.configure_view(
    strokeWidth=0
).configure_title(
    anchor='start', fontSize= 35
).configure_axis(
    labelFontSize=24,
    titleFontSize=24
).configure_legend(
    labelFontSize = 40)
# Out:
# alt.VConcatChart(...)

# %%
#chart_abcd_labeled.save("test.png")

# %%
metadata_300 =  pd.read_csv("../out/nextstrain_builds/500_new/results/hmpxv1/metadata.tsv", sep = "\t")

# %%
metadata_300
# Out:
#        strain accession genbank_accession_rev  \
# 0    ON676708  ON676708            ON676708.1
# 1    OP185715  OP185715            OP185715.1
# 2    ON676704  ON676704            ON676704.1
# 3    OP743357  OP743357            OP743357.1
# 4    ON959131  ON959131            ON959131.1
# ..        ...       ...                   ...
# 584  OX297403  OX297403            OX297403.1
# 585  OX336038  OX336038            OX336038.1
# 586  OX291676  OX291676            OX291676.1
# 587  OX291694  OX291694            OX291694.1
# 588  OX336004  OX336004            OX336004.1
#
#                           strain_original        date         region  \
# 0                        MPXV_USA_2021_MD  2021-11-XX  North America
# 1                    MPXV_USA_2022_CO0002  2022-05-XX  North America
# 2                     MPXV_USA_2022_FL002  2022-05-XX  North America
# 3    MPXV/Human/USA/UT-UPHL-82200022/2022  2022-05-21  North America
# 4                     MPXV_USA_2022_IL001  2022-05-XX  North America
# ..                                    ...         ...            ...
# 584                                   RNA  2022-08-09         Europe
# 585                                   RNA  2022-08-31         Europe
# 586                                   RNA  2022-08-01         Europe
# 587                                   RNA  2022-08-01         Europe
# 588                                   RNA  2022-08-26         Europe
#
#       country  division location          host  ... nonACGTN QC_missing_data  \
# 0         USA  Maryland      NaN  Homo sapiens  ...      0.0            good
# 1         USA  Colorado      NaN  Homo sapiens  ...      0.0            good
# 2         USA   Florida      NaN  Homo sapiens  ...      0.0            good
# 3         USA       NaN      NaN  Homo sapiens  ...      0.0            good
# 4         USA  Illinois      NaN  Homo sapiens  ...      0.0            good
# ..        ...       ...      ...           ...  ...      ...             ...
# 584  Slovakia       NaN      NaN  Homo sapiens  ...      1.0            good
# 585  Slovakia       NaN      NaN  Homo sapiens  ...      1.0            good
# 586  Slovakia       NaN      NaN  Homo sapiens  ...      1.0            good
# 587  Slovakia       NaN      NaN  Homo sapiens  ...      1.0            good
# 588  Slovakia       NaN      NaN  Homo sapiens  ...      1.0            good
#
#     QC_mixed_sites  QC_rare_mutations QC_frame_shifts QC_stop_codons  \
# 0             good               good            good           good
# 1             good               good            good           good
# 2             good               good            good           good
# 3             good               good            good           good
# 4             good               good            good           good
# ..             ...                ...             ...            ...
# 584           good               good            good           good
# 585           good               good            good           good
# 586           good               good            good           good
# 587           good               good            good           good
# 588           good               good            good           good
#
#        frame_shifts  is_reverse_complement  \
# 0               NaN                  False
# 1               NaN                  False
# 2               NaN                  False
# 3               NaN                  False
# 4               NaN                  False
# ..              ...                    ...
# 584             NaN                  False
# 585             NaN                  False
# 586  OPG044:146-150                  False
# 587             NaN                  False
# 588             NaN                  False
#
#                                                authors  \
# 0    Gigante,C.M., Myers,R., Seabolt,M.H., Wilkins,...
# 1    Gigante,C.M., Steidley,B., Seabolt,M.H., Zhao,...
# 2    Gigante,C.M., Lee,P., Seabolt,M.H., Wilkins,K....
# 3    Iverson,T., Oakeson,K.F., Young,E.L., Wagner,J...
# 4    Gigante,C.M., Ghinai,I., Seabolt,M.H., Zhao,H....
# ..                                                 ...
# 584                                                NaN
# 585                                                NaN
# 586                                                NaN
# 587                                                NaN
# 588                                                NaN
#
#                                            institution
# 0    Division of High-Consequence Pathogens & Patho...
# 1                                       CDC, DHCPP-PRB
# 2    Division of High-Consequence Pathogens & Patho...
# 3                        Utah Public Health Laboratory
# 4    Centers for Disease Control and Prevention, Di...
# ..                                                 ...
# 584                                                NaN
# 585                                                NaN
# 586                                                NaN
# 587                                                NaN
# 588                                                NaN
#
# [589 rows x 30 columns]

# %%
meta_300 = metadata_300[metadata_300['date'].notna()]
meta_300["year_month"] = meta_300['date'].str.rsplit("-", 1).str[-0].tolist()
meta_300 = meta_300[meta_300.year_month.str.contains('XX*')==False]
meta_300 = meta_300[meta_300.year_month != "2021-11"]
meta_300
# Out:
#        strain accession genbank_accession_rev  \
# 1    OP185715  OP185715            OP185715.1
# 2    ON676704  ON676704            ON676704.1
# 3    OP743357  OP743357            OP743357.1
# 4    ON959131  ON959131            ON959131.1
# 5    ON676705  ON676705            ON676705.1
# ..        ...       ...                   ...
# 584  OX297403  OX297403            OX297403.1
# 585  OX336038  OX336038            OX336038.1
# 586  OX291676  OX291676            OX291676.1
# 587  OX291694  OX291694            OX291694.1
# 588  OX336004  OX336004            OX336004.1
#
#                           strain_original        date         region  \
# 1                    MPXV_USA_2022_CO0002  2022-05-XX  North America
# 2                     MPXV_USA_2022_FL002  2022-05-XX  North America
# 3    MPXV/Human/USA/UT-UPHL-82200022/2022  2022-05-21  North America
# 4                     MPXV_USA_2022_IL001  2022-05-XX  North America
# 5                     MPXV_USA_2022_UT001  2022-05-XX  North America
# ..                                    ...         ...            ...
# 584                                   RNA  2022-08-09         Europe
# 585                                   RNA  2022-08-31         Europe
# 586                                   RNA  2022-08-01         Europe
# 587                                   RNA  2022-08-01         Europe
# 588                                   RNA  2022-08-26         Europe
#
#       country  division location          host  ... QC_missing_data  \
# 1         USA  Colorado      NaN  Homo sapiens  ...            good
# 2         USA   Florida      NaN  Homo sapiens  ...            good
# 3         USA       NaN      NaN  Homo sapiens  ...            good
# 4         USA  Illinois      NaN  Homo sapiens  ...            good
# 5         USA      Utah      NaN  Homo sapiens  ...            good
# ..        ...       ...      ...           ...  ...             ...
# 584  Slovakia       NaN      NaN  Homo sapiens  ...            good
# 585  Slovakia       NaN      NaN  Homo sapiens  ...            good
# 586  Slovakia       NaN      NaN  Homo sapiens  ...            good
# 587  Slovakia       NaN      NaN  Homo sapiens  ...            good
# 588  Slovakia       NaN      NaN  Homo sapiens  ...            good
#
#     QC_mixed_sites QC_rare_mutations  QC_frame_shifts QC_stop_codons  \
# 1             good              good             good           good
# 2             good              good             good           good
# 3             good              good             good           good
# 4             good              good             good           good
# 5             good              good             good           good
# ..             ...               ...              ...            ...
# 584           good              good             good           good
# 585           good              good             good           good
# 586           good              good             good           good
# 587           good              good             good           good
# 588           good              good             good           good
#
#        frame_shifts is_reverse_complement  \
# 1               NaN                 False
# 2               NaN                 False
# 3               NaN                 False
# 4               NaN                 False
# 5               NaN                 False
# ..              ...                   ...
# 584             NaN                 False
# 585             NaN                 False
# 586  OPG044:146-150                 False
# 587             NaN                 False
# 588             NaN                 False
#
#                                                authors  \
# 1    Gigante,C.M., Steidley,B., Seabolt,M.H., Zhao,...
# 2    Gigante,C.M., Lee,P., Seabolt,M.H., Wilkins,K....
# 3    Iverson,T., Oakeson,K.F., Young,E.L., Wagner,J...
# 4    Gigante,C.M., Ghinai,I., Seabolt,M.H., Zhao,H....
# 5    Gigante,C.M., Atkinson,A., Seabolt,M.H., Wilki...
# ..                                                 ...
# 584                                                NaN
# 585                                                NaN
# 586                                                NaN
# 587                                                NaN
# 588                                                NaN
#
#                                            institution  year_month
# 1                                       CDC, DHCPP-PRB     2022-05
# 2    Division of High-Consequence Pathogens & Patho...     2022-05
# 3                        Utah Public Health Laboratory     2022-05
# 4    Centers for Disease Control and Prevention, Di...     2022-05
# 5    Division of High-Consequence Pathogens & Patho...     2022-05
# ..                                                 ...         ...
# 584                                                NaN     2022-08
# 585                                                NaN     2022-08
# 586                                                NaN     2022-08
# 587                                                NaN     2022-08
# 588                                                NaN     2022-08
#
# [588 rows x 31 columns]

# %%
meta_300.institution.value_counts().reset_index().in
# Out:
#                                                 index  institution
# 0   National Institute of Health Doutor Ricardo Jo...           64
# 1                      UKHSA, Research and Evaluation           64
# 2   Robert Koch Institute, Centre for Biological T...           62
# 3   Los Angeles County Public Health Laboratories,...           57
# 4   National Microbiology Laboratory, Public Healt...           44
# 5   Institute of Microbiology and Immunology, Facu...           29
# 6   Laboratorio Departamental de Salud Publica de ...           24
# 7                                      CDC, DHCPP-PRB           17
# 8                 IHU - Mediterranee Infection, MEPHI           16
# 9   Instituto Nacional de Salud, Direccion de Inve...           15
# 10  Institute of Tropica Medicine, Department of C...           12
# 11  Medical University of Vienna, Center for Virology           11
# 12  Centre for Biological Threats, Highly Pathogen...           10
# 13  Instituto Nacional de Salud Peru, Laboratorio ...           10
# 14                   UW Virology, Laboratory Medicine           10
# 15  Universidad de Cartagena, Laboratorio de Inves...            8
# 16  Institute National de Saude Doutor Ricardo Jor...            6
# 17  Royal Infirmary of Edinburgh, Viral Genotyping...            6
# 18  Southern Illinois University, Molecular Biolog...            6
# 19  Division of High-Consequence Pathogens & Patho...            5
# 20  Laboratorio Departamental de Salud Publica de ...            5
# 21  Rush University Meical Center, Regional Innova...            5
# 22  Universidad Tecnologica de Pereira, Laboratori...            5
# 23                                         CDPH, VRDL            4
# 24                   Research & Evaluation, UKHSA, UK            4
# 25  Delaware Public Health Lab, Sequencing/Bioinfo...            4
# 26  Centers for Disease Control and Prevention, Di...            4
# 27  University of Nebraska Medical Center, Environ...            3
# 28  INMI Lazzaro Spallanzani IRCCS, Laboratory of ...            3
# 29  Laboratory of Viorology, University Hospital o...            2
# 30  Laboratory for Diagnostics of Zoonoses & WHO C...            2
# 31                      Utah Public Health Laboratory            2
# 32  Insitut Pasteur, Environment and Infectious Ri...            2
# 33  Biomedical research institute (INIBIC), Microb...            2
# 34  Microbiology, Immunology & Transplantation, KU...            2
# 35  University Hospitals of Geneva, Laboratory of ...            2
# 36  Microbial Genomics, Hospital General Universit...            2
# 37                         Hopital Saint Louis, Paris            1
# 38  Centre for Clinical Infection & Diagnostics Re...            1
# 39  Virology, GENomique EPIdemiologique das maladi...            1
# 40  New Jersey Department of Health, Public Health...            1
# 41  Department of Health, Utah Public Health Labor...            1
# 42  Laboratory of Virology, INMI Lazzaro Spallanza...            1
# 43   Genomics & Epigenomics, AREA Science Park, Italy            1
# 44  University of Palermo, Department of Health Pr...            1
# 45  Alberta Precision Laboratories, Provincial Pub...            1
# 46  Microbiology, Hospital Universitari Germans Tr...            1
# 47                              US Air Force, USAFSAM            1
# 48  Istituto Zooprofilattico Sperimentale del Mezz...            1
# 49                APHP Pitie Salpetriere SU, Virology            1

# %%
country_300_count = meta_300.groupby(["year_month"])["country"].value_counts().reset_index(name="count")

# %%
country_300_count.groupby("country")["count"].sum()

# %%
country_300_count['order'] = country_300_count['country'].replace(
    {val: i for i, val in enumerate(colors.keys())}
)

alt.Chart(country_300_count).mark_bar(size = 70).encode(
    alt.X("year_month:T",axis=alt.Axis(title = "", grid=False, )),
    alt.Y("count",axis=alt.Axis( grid=False, offset = 30)), 
    alt.Color("country:N", scale=alt.Scale(domain=list(colors.keys()), range=list(colors.values())), legend=alt.Legend(title = "Country", orient = "right",offset = -125, labelFontSize = 14, titleFontSize = 14, symbolSize = 110)),
    alt.Order("order", sort= "descending")).properties(
    width = 800,
    height = 600
).configure_view(
    strokeWidth=0)

# %%
metadata_1000 =  pd.read_csv("../out/nextstrain_builds/1000_prevalence_subsampling/results/hmpxv1/metadata.tsv", sep = "\t")

# %%
metadata_1000.institution.value_counts()
# Out:
# Los Angeles County Public Health Laboratories, Los Angeles County Department of Public Health                                                           240
# UW Virology, Laboratory Medicine                                                                                                                        131
# UKHSA, Research and Evaluation                                                                                                                           75
# CDC, DHCPP-PRB                                                                                                                                           69
# Robert Koch Institute, Centre for Biological Threats, Highly Pathogenic Viruses                                                                          61
# National Institute of Health Doutor Ricardo Jorge, Portugal (INSA), Department of Infectious Diseases                                                    50
# Laboratorio Departamental de Salud Publica de Antioquia, Antioquia                                                                                       29
# Instituto Nacional de Salud, Direccion de Investigacion en Salud Publica                                                                                 28
# National Microbiology Laboratory, Public Health Agency of Canada                                                                                         27
# Institute National de Saude Doutor Ricardo Jorge (INSA), Portugal                                                                                        26
# CDPH, VRDL                                                                                                                                               20
# IHU - Mediterranee Infection, MEPHI                                                                                                                      18
# Centre for Biological Threats, Highly Pathogenic Viruses, Robert Koch Institute, Germany                                                                 13
# New Jersey Department of Health, Public Health and Environmental Laboratories                                                                            12
# Rush University Meical Center, Regional Innovative Public Health Laboratory (RIPHL)                                                                      12
# University of Nebraska Medical Center, Environmental, Agricultural, and Occupational Health                                                              12
# Universidad Tecnologica de Pereira, Laboratorio de Biologia Molecular y Biotecnologia / Facultad de ciencias de la salud                                 11
# Royal Infirmary of Edinburgh, Viral Genotyping Reference Laboratory                                                                                      10
# Southern Illinois University, Molecular Biology, Microbiology, and Biochemistry                                                                           9
# Institute of Tropica Medicine, Department of Clinical Sciences                                                                                            9
# Minnesota Department of Health                                                                                                                            9
# Delaware Public Health Lab, Sequencing/Bioinformatics                                                                                                     8
# Universidad de Cartagena, Laboratorio de Investigacion Molecular (UNIMOL)                                                                                 8
# University of North Carolina at Chapel Hill, Department of Genetics                                                                                       5
# Research & Evaluation, UKHSA, UK                                                                                                                          4
# INMI Lazzaro Spallanzani IRCCS, Laboratory of Virology                                                                                                    3
# Instituto Nacional de Salud Peru, Laboratorio de Biotecnologia y Biologia Molecular                                                                       3
# Utah Public Health Laboratory                                                                                                                             3
# Medical University of Vienna, Center for Virology                                                                                                         3
# Insitut Pasteur, Environment and Infectious Risks Unit                                                                                                    2
# University Hospitals of Geneva, Laboratory of Virology                                                                                                    2
# US Air Force, USAFSAM                                                                                                                                     2
# Laboratory of Viorology, University Hospital of Geneva, Switzerland                                                                                       2
# Microbiology, Immunology & Transplantation, KU Leuven, Rega Institute, Belgium                                                                            2
# Biomedical research institute (INIBIC), Microbiology                                                                                                      2
# Istituto Zooprofilattico Sperimentale del Mezzogiorno, Hanimal Health                                                                                     1
# Hopital Saint Louis, Paris                                                                                                                                1
# Idaho Bureau of Laboratories, Molecular Epidemiology                                                                                                      1
# University of Palermo, Department of Health Promotion Sciences Maternal and Infant Care, Internal Medicine and Medical Specialties "G. D'Alessandro"      1
# Laboratorio Departamental de Salud Publica de Antioquia                                                                                                   1
# Laboratory of Virology, INMI Lazzaro Spallanzani IRCCS, Italy                                                                                             1
# Virology, GENomique EPIdemiologique das maladies Infectieuses, France                                                                                     1
# Microbiol Genomics & Bioinformatics, Bundeswehr Institute of Microbiology, Germany                                                                        1
# Division of High-Consequence Pathogens & Pathology, Centers for Disease Control & Prevention (US CDC), USA                                                1
# Microbiology, Hospital Universitari Germans Trias i Pujol, Spain                                                                                          1
# APHP Pitie Salpetriere SU, Virology                                                                                                                       1
# Name: institution, dtype: int64

# %%
metadata_1000 = metadata_1000[metadata_1000['date'].notna()]
metadata_1000["year_month"] = metadata_1000['date'].str.rsplit("-", 1).str[-0].tolist()
metadata_1000 = metadata_1000[metadata_1000.year_month.str.contains('XX*')==False]
metadata_1000 = metadata_1000[metadata_1000.year_month != "2021-11"]
metadata_1000

# %%
country_1000_count = metadata_1000.groupby(["year_month"])["country"].value_counts().reset_index(name="count")

# %%
country_1000_count.groupby("country")["count"].sum()
