# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../monkeypox-build/data/nextstrain__metadata_3000.tsv", sep = "\t")

# %%
df
# Out:
#                                                 strain        date  \
# 0                                                 4061  2022-05-20
# 1                                                 8887  2022-06-06
# 2                                              9000231  2022-07-25
# 3                                              9000289  2022-08-01
# 4                                              9000327  2022-08-17
# ...                                                ...         ...
# 3008             hMPX/Human/USA/CA-LACPHL-MA00053/2022  2022-07-25
# 3009              MPX/Human/USA/CA-LACPHL-MA00237/2022  2022-07-20
# 3010              MPX/Human/USA/CA-LACPHL-MA00144/2022  2022-08-30
# 3011  Monkeypox virus/Human/USA/CA-LACPHL-MA00379/2022  2022-10-12
# 3012             MPXV/Human/USA/CA-LACPHL-MA00303/2022  2022-09-29
#
#               host recency date_submitted lineage         region  \
# 0     Homo sapiens   Older     2022-06-24     B.1         Europe
# ...

# %%
north_america = ['Canada','USA']
western_europe = ['Austria','Germany','Switzerland','United Kingdom','France','Belgium']
central_europe = ['Slovakia','Slovenia']
southern_europe = ['Italy','Portugal','Spain']
south_american = ['Colombia','Peru']

# %%
df["region_coarse"] = np.nan
df.region_coarse[df.country.isin(north_america)] = "North America"
df['region_coarse'][df.country.isin(western_europe)] = "Western Europe"
df['region_coarse'][df.country.isin(central_europe)] = "Central Europe"
df['region_coarse'][df.country.isin(southern_europe)] = "Southern Europe"
df['region_coarse'][df.country.isin(south_american)] = "South America"
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_26532/557305204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.region_coarse[df.country.isin(north_america)] = "North America"

# %%
df = df[["accession", "date", "region_coarse", "country", "strain"]]
df
# Out:
#      accession        date    region_coarse         country  \
# 0     ON838940  2022-05-20  Southern Europe           Spain
# 1     ON838939  2022-06-06  Southern Europe           Spain
# 2     OP413713  2022-07-25   Western Europe  United Kingdom
# 3     OP413714  2022-08-01   Western Europe  United Kingdom
# 4     OP413715  2022-08-17   Western Europe  United Kingdom
# ...        ...         ...              ...             ...
# 3008  OP440544  2022-07-25    North America             USA
# 3009  OP722496  2022-07-20    North America             USA
# 3010  OP539929  2022-08-30    North America             USA
# 3011  OQ330985  2022-10-12    North America             USA
# 3012  OP890537  2022-09-29    North America             USA
#
#                                                 strain
# 0                                                 4061
# 1                                                 8887
# 2                                              9000231
# ...

# %%
df.to_csv("../monkeypox-build/data/metadata_region_3000_all.tsv", sep = "\t")
