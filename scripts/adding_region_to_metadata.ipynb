# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../monkeypox-build/data/nextstrain__metadata_1000.tsv", sep = "\t")

# %%
df
# Out:
#                                                 strain        date  \
# 0                                                 4061  2022-05-20
# 1                                                 8887  2022-06-06
# 2                                              9000231  2022-07-31
# 3                                              9000289  2022-08-01
# 4                                              9000369  2022-08-01
# ...                                                ...         ...
# 1071  Monkeypox virus/Human/USA/CA-LACPHL-MA00379/2022  2022-10-12
# 1072                              MPXV_USA_2022_AZ0007  2022-09-11
# 1073             MPXV/Human/USA/CA-LACPHL-MA00288/2022  2022-10-04
# 1074                                          B1221120  2022-11-09
# 1075                                          B1221119  2022-11-08
#
#               host       recency lineage date_submitted         country  \
# 0     Homo sapiens         Older     B.1     2022-06-24           Spain
# 1     Homo sapiens         Older     B.1     2022-06-24           Spain
# 2     Homo sapiens         Older   B.1.2     2022-09-12  United Kingdom
# 3     Homo sapiens         Older   B.1.7     2022-09-12  United Kingdom
# 4     Homo sapiens         Older   B.1.2     2022-09-27  United Kingdom
# ...            ...           ...     ...            ...             ...
# 1071  Homo sapiens  3-7 days ago   B.1.2     2023-01-26             USA
# 1072  Homo sapiens         Older   B.1.2     2022-12-15             USA
# 1073  Homo sapiens         Older   B.1.2     2022-11-24             USA
# 1074  Homo sapiens         Older   B.1.2     2022-12-02             USA
# 1075  Homo sapiens         Older   B.1.2     2022-12-02             USA
#
#      clade_membership         region  \
# 0                 IIb         Europe
# 1                 IIb         Europe
# 2                 IIb         Europe
# 3                 IIb         Europe
# 4                 IIb         Europe
# ...               ...            ...
# 1071              IIb  North America
# 1072              IIb  North America
# 1073              IIb  North America
# 1074              IIb  North America
# 1075              IIb  North America
#
#                                                  author accession  \
# 0     de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...  ON838940
# 1     de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...  ON838939
# 2     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413713
# 3     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP413714
# 4     Groves,N., Osman,K.L., Lewandowski,K.S., Carte...  OP536750
# ...                                                 ...       ...
# 1071          Hemarajata,P., Green,N.M., Garrigues,J.M.  OQ330985
# 1072  Gigante,C., Francis,D., Zhao,H., Batra,D., Het...  OQ054243
# 1073          Hemarajata,P., Green,N.M., Garrigues,J.M.  OP890546
# 1074                              Bajwa,M.I., Miller,H.  OP935997
# 1075                              Bajwa,M.I., Miller,H.  OP935996
#
#       GA_CT_fraction  dinuc_context_fraction
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2               0.83                     0.8
# 3               1.00                     1.0
# 4               1.00                     1.0
# ...              ...                     ...
# 1071            1.00                     1.0
# 1072             NaN                     NaN
# 1073            1.00                     1.0
# 1074             NaN                     NaN
# 1075            1.00                     1.0
#
# [1076 rows x 13 columns]

# %%
north_america = ['Canada','USA']
western_europe = ['Austria','Germany','Switzerland','United Kingdom','France','Belgium']
central_europe = ['Slovakia','Slovenia']
southern_europe = ['Italy','Portugal','Spain']
south_american = ['Colombia','Peru']

# %%
df["region_coarse"] = np.nan
df.region_coarse[df.country.isin(north_america)] = "North America"
df['region_coarse'][df.country.isin(western_europe)] = "Western Europe"
df['region_coarse'][df.country.isin(central_europe)] = "Central Europe"
df['region_coarse'][df.country.isin(southern_europe)] = "Southern Europe"
df['region_coarse'][df.country.isin(south_american)] = "South America"
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_11344/557305204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.region_coarse[df.country.isin(north_america)] = "North America"

# %%
df = df[["accession", "date", "region_coarse", "country", "strain"]]
df
# Out:
#      accession        date    region_coarse         country  \
# 0     ON838940  2022-05-20  Southern Europe           Spain
# 1     ON838939  2022-06-06  Southern Europe           Spain
# 2     OP413713  2022-07-31   Western Europe  United Kingdom
# 3     OP413714  2022-08-01   Western Europe  United Kingdom
# 4     OP536750  2022-08-01   Western Europe  United Kingdom
# ...        ...         ...              ...             ...
# 1071  OQ330985  2022-10-12    North America             USA
# 1072  OQ054243  2022-09-11    North America             USA
# 1073  OP890546  2022-10-04    North America             USA
# 1074  OP935997  2022-11-09    North America             USA
# 1075  OP935996  2022-11-08    North America             USA
#
#                                                 strain
# 0                                                 4061
# 1                                                 8887
# 2                                              9000231
# 3                                              9000289
# 4                                              9000369
# ...                                                ...
# 1071  Monkeypox virus/Human/USA/CA-LACPHL-MA00379/2022
# 1072                              MPXV_USA_2022_AZ0007
# 1073             MPXV/Human/USA/CA-LACPHL-MA00288/2022
# 1074                                          B1221120
# 1075                                          B1221119
#
# [1076 rows x 5 columns]

# %%
df.to_csv("../monkeypox-build/data/metadata_region_1000.tsv", sep = "\t")
