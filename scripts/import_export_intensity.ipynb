# %%
import pandas as pd
import numpy as np
import os, glob
import altair as alt

# %% [markdown]
# ## the following analyses are based on calculations from https://www.sciencedirect.com/science/article/pii/S0092867420304840#sec4

# %%
#first read in air traffic data for countries of interest
air_folder = "../data/2022_apr_dec/"

concat_air = pd.DataFrame()
count = 0
for filename in glob.glob("../data/2022_apr_dec/specific_countries/*"):
    if count == 0:
        concat_air =  pd.read_csv(filename)
        count+=1
    else:
        temp = pd.read_csv(filename)
        concat_air = pd.concat([concat_air,temp])

concat_air["Date"] = concat_air.apply(lambda row: str(row.Month) + "-01-2022", axis = 1)
concat_air["Date"] = pd.to_datetime(concat_air["Date"])

# %%
concat_air
# Out:
#      Month   Orig Country    Dest Country  Total Market Pax       Date
# 0       12        Austria         Austria              6428 2022-12-01
# 1       12        Austria         Belgium             19280 2022-12-01
# 2       12        Austria          Canada              4165 2022-12-01
# 3       12        Austria        Colombia               986 2022-12-01
# 4       12        Austria          France             40413 2022-12-01
# ..     ...            ...             ...               ...        ...
# 210     11  United States        Slovenia               811 2022-11-01
# 211     11  United States           Spain            125618 2022-11-01
# 212     11  United States     Switzerland             60465 2022-11-01
# 213     11  United States  United Kingdom            527992 2022-11-01
# 214     11  United States   United States          47158263 2022-11-01
#
# [1928 rows x 5 columns]

# %%
concat_air["year-month"] = pd.to_datetime(concat_air['Date']).dt.to_period('M')

# %%
#now read in population sizes for each country
# taken from the world bank https://data.worldbank.org/indicator/SP.POP.TOTL

pop = pd.read_csv("../data/country_pop.csv")

# %%
#list of countries included in glm analysis based on having >5 sequences 
countries = ["Austria",
"Belgium",
"Canada",
"Colombia",
"France",
"Germany",
"Italy",
"Peru",
"Portugal",
"Slovak Republic",
"Slovenia",
"Spain",
"Switzerland",
"United States",
"United Kingdom",
]

regions = ["NorthAmerica", "WesternEurope", "CentralEurope", "SouthernEurope", "SouthAmerica"]

north_america = ['Canada','United States of America']
western_europe = ['Austria','Germany','Switzerland','United Kingdom','France','Belgium']
central_europe = ['Slovakia','Slovenia']
southern_europe = ['Italy','Portugal','Spain']
south_american = ['Colombia','Peru']

# %%
pop = pop[pop["Country Name"].isin(countries)]
pop["Country Name"][pop["Country Name"] == "Slovak Republic"] = "Slovakia"

# %%
pop
# Out:
#        Country Name         2021
# 14          Austria    8955797.0
# 17          Belgium   11592952.0
# 35           Canada   38246108.0
# 37      Switzerland    8703405.0
# 45         Colombia   51516562.0
# 55          Germany   83196078.0
# 70            Spain   47415750.0
# 77           France   67749632.0
# 81   United Kingdom   67326569.0
# 116           Italy   59109668.0
# 186            Peru   33715471.0
# 194        Portugal   10325147.0
# 221        Slovakia    5447247.0
# 222        Slovenia    2108079.0
# 251   United States  331893745.0

# %%
## now read in prevalence estimates from Marlin's evofr models
case_prevalence = pd.read_csv("../case-rt-analysis/estimates/case-prevalence-estimates_country.tsv", sep="\t", parse_dates= ["date"])

# %%
case_prevalence.set_index('date', inplace=True)
case_prevalence.index = pd.to_datetime(case_prevalence.index)
month_prevalence = case_prevalence.groupby(["location"]).resample('1M').sum().reset_index()
month_prevalence["year-month"]= pd.to_datetime(month_prevalence['date']).dt.to_period('M')

# %%
month_prevalence
# Out:
#           location       date    median_prev  prev_upper_80  prev_lower_80  \
# 0          Austria 2022-05-31     147.193414     147.193780     147.193085
# 1          Austria 2022-06-30    1114.559632    1114.565076    1114.554897
# 2          Austria 2022-07-31    2694.629072    2694.650442    2694.603314
# 3          Austria 2022-08-31    2445.611126    2445.639375    2445.576886
# 4          Austria 2022-09-30    1008.003817    1008.017584    1007.986420
# ..             ...        ...            ...            ...            ...
# 124  United States 2022-09-30  202887.613900  210180.939500  196339.247200
# 125  United States 2022-10-31   77762.170300   80329.301200   74725.048000
# 126  United States 2022-11-30   29969.925100   31078.777010   28645.900280
# 127  United States 2022-12-31   19934.721940   20883.921470   18734.466340
# 128  United States 2023-01-31    9347.516730    9978.507450    8738.482000
#
#     year-month
# 0      2022-05
# 1      2022-06
# 2      2022-07
# 3      2022-08
# 4      2022-09
# ..         ...
# 124    2022-09
# 125    2022-10
# 126    2022-11
# 127    2022-12
# 128    2023-01
#
# [129 rows x 6 columns]

# %%
import_dict = {}
for month in concat_air["year-month"].unique():
    for place in concat_air["Dest Country"].unique():
        import_list = []
        import_dict[str(place) +"." + str(month)] = []
        for orig in concat_air["Orig Country"].unique():
            #prev= (concat_air["Total Market Pax"].loc[(concat_air["year-month"] == month) & (concat_air["Dest Country"] == place) & (concat_air["Orig Country"] == orig)].tolist()[0])
            #print(month, place, orig, prev, "\n")
            if place != orig:
                try:
                    import_risk = (concat_air["Total Market Pax"].loc[(concat_air["year-month"] == month) & (concat_air["Dest Country"] == place) & (concat_air["Orig Country"] == orig)].tolist()[0]) * \
                    ((month_prevalence.median_prev.loc[(month_prevalence["year-month"] == month) & (month_prevalence.location == orig)].tolist()[0])/((pop["2021"].loc[pop["Country Name"] == orig].tolist()[0]) *1000 ))
                    import_list.append(import_risk)
                    #print(month, place, orig, import_risk, prev, "\n")
                except IndexError:
                    pass

        import_dict[str(place) +"." + str(month)] = {"place" : place, "year-month": month, "import_risk":np.sum(np.array(import_list))}

# %%
"""this will generate a multi-index dataframe from the migrations dictionary"""
import_df = pd.DataFrame.from_dict({(i): import_dict[i] 
                       for i in import_dict.keys()}, orient='index')

import_df.reset_index(inplace=True)
#migrations_df.rename(columns={'level_0': 'tree_number', 'level_1': 'migration_event_number'}, inplace=True)

import_df
# Out:
#                       index           place year-month  import_risk
# 0           Austria.2022-12         Austria    2022-12     0.021989
# 1           Belgium.2022-12         Belgium    2022-12     0.038758
# 2            Canada.2022-12          Canada    2022-12     0.064917
# 3          Colombia.2022-12        Colombia    2022-12     0.034265
# 4            France.2022-12          France    2022-12     0.117733
# ..                      ...             ...        ...          ...
# 130        Slovenia.2022-11        Slovenia    2022-11     0.000457
# 131           Spain.2022-11           Spain    2022-11     0.134270
# 132     Switzerland.2022-11     Switzerland    2022-11     0.047357
# 133  United Kingdom.2022-11  United Kingdom    2022-11     0.291823
# 134   United States.2022-11   United States    2022-11     0.239329
#
# [135 rows x 4 columns]

# %%
import_df["year-month"] = import_df["year-month"].dt.to_timestamp()

# %%
alt.Chart(import_df).mark_line().encode(
    alt.X("year-month:T"),
    alt.Y("import_risk"), 
    alt.Color("place:N"))
# Out:
# alt.Chart(...)

# %%
## now do the same but by region to compare to glm

# %%
region = {'Canada':'North America',
          'United States':'North America',
         'Finland':'Northern Europe',
           'Austria': 'Western Europe',
        'Germany':'Western Europe', 
        'Switzerland':'Western Europe',
         'United Kingdom':'Western Europe',
        'France':'Western Europe',
        'Belgium':'Western Europe',
        'Netherlands':'Western Europe',
        'Slovakia':'Central Europe',
        'Slovenia':'Central Europe',
        'Italy':'Southern Europe',
        'Portugal':'Southern Europe',
        'Spain':'Southern Europe',
         'Colombia':'South America',
          
        'Peru':'South America'}

# %%
concat_air["region_orig"] = np.nan
concat_air["region_dest"] = np.nan
concat_air.region_orig = concat_air["Orig Country"].map(region)
concat_air.region_dest = concat_air["Dest Country"].map(region)
region_air=  concat_air.groupby(["year-month","region_orig", "region_dest"])["Total Market Pax"].sum().reset_index()

pop["region"] = np.nan
pop.region = pop["Country Name"].map(region)
region_pop = pop.groupby(["region"])["2021"].sum().reset_index()

month_prevalence["region"] = np.nan
month_prevalence.region = month_prevalence["location"].map(region)
region_prev = month_prevalence.groupby(["year-month","region"])["median_prev"].sum().reset_index()

# %%
import_dict = {}
for month in region_air["year-month"].unique():
    for place in region_air["region_dest"].unique():
        import_list = []
        import_dict[str(place) +"." + str(month)] = []
        for orig in region_air["region_orig"].unique():
            #prev= (concat_air["Total Market Pax"].loc[(concat_air["year-month"] == month) & (concat_air["Dest Country"] == place) & (concat_air["Orig Country"] == orig)].tolist()[0])
            #print(month, place, orig, prev, "\n")
            if orig != place:
                try:
                    import_risk = (region_air["Total Market Pax"].loc[(region_air["year-month"] == month) & (region_air["region_dest"] == place) & (region_air["region_orig"] == orig)].tolist()[0]) * \
                    ((region_prev.median_prev.loc[(region_prev["year-month"] == month) & (region_prev.region == orig)].tolist()[0])/((region_pop["2021"].loc[region_pop["region"] == orig].tolist()[0]) *1000))
                    import_list.append(import_risk)
                    #print(month, place, orig, import_risk, prev, "\n")
                except IndexError:
                    pass

        import_dict[str(place) +"." + str(month)] = {"place" : place, "year-month": month, "import_risk":np.sum(np.array(import_list))}

# %%
import_dict
# Out:
# {'North America.2022-04': {'place': 'North America',
#   'year-month': Period('2022-04', 'M'),
#   'import_risk': 0.0},
#  'Southern Europe.2022-04': {'place': 'Southern Europe',
#   'year-month': Period('2022-04', 'M'),
#   'import_risk': 0.0},
#  'Western Europe.2022-04': {'place': 'Western Europe',
#   'year-month': Period('2022-04', 'M'),
#   'import_risk': 0.0},
#  'Central Europe.2022-04': {'place': 'Central Europe',
#   'year-month': Period('2022-04', 'M'),
#   'import_risk': 0.0},
#  'South America.2022-04': {'place': 'South America',
#   'year-month': Period('2022-04', 'M'),
#   'import_risk': 0.0},
#  'North America.2022-05': {'place': 'North America',
#   'year-month': Period('2022-05', 'M'),
#   'import_risk': 0.08157338602948179},
#  'Southern Europe.2022-05': {'place': 'Southern Europe',
#   'year-month': Period('2022-05', 'M'),
#   'import_risk': 0.24945490462950873},
#  'Western Europe.2022-05': {'place': 'Western Europe',
#   'year-month': Period('2022-05', 'M'),
#   'import_risk': 0.41554398646033497},
#  'Central Europe.2022-05': {'place': 'Central Europe',
#   'year-month': Period('2022-05', 'M'),
#   'import_risk': 0.0023538372610389597},
#  'South America.2022-05': {'place': 'South America',
#   'year-month': Period('2022-05', 'M'),
#   'import_risk': 0.005386597204062746},
#  'North America.2022-06': {'place': 'North America',
#   'year-month': Period('2022-06', 'M'),
#   'import_risk': 0.6891193096072652},
#  'Southern Europe.2022-06': {'place': 'Southern Europe',
#   'year-month': Period('2022-06', 'M'),
#   'import_risk': 1.773727472993239},
#  'Western Europe.2022-06': {'place': 'Western Europe',
#   'year-month': Period('2022-06', 'M'),
#   'import_risk': 3.226133588326355},
#  'Central Europe.2022-06': {'place': 'Central Europe',
#   'year-month': Period('2022-06', 'M'),
#   'import_risk': 0.017731324330101536},
#  'South America.2022-06': {'place': 'South America',
#   'year-month': Period('2022-06', 'M'),
#   'import_risk': 0.051758639280443025},
#  'North America.2022-07': {'place': 'North America',
#   'year-month': Period('2022-07', 'M'),
#   'import_risk': 2.6701926657121198},
#  'Southern Europe.2022-07': {'place': 'Southern Europe',
#   'year-month': Period('2022-07', 'M'),
#   'import_risk': 5.432429584858898},
#  'Western Europe.2022-07': {'place': 'Western Europe',
#   'year-month': Period('2022-07', 'M'),
#   'import_risk': 9.791414317465344},
#  'Central Europe.2022-07': {'place': 'Central Europe',
#   'year-month': Period('2022-07', 'M'),
#   'import_risk': 0.06005274513294079},
#  'South America.2022-07': {'place': 'South America',
#   'year-month': Period('2022-07', 'M'),
#   'import_risk': 0.19686883232032132},
#  'North America.2022-08': {'place': 'North America',
#   'year-month': Period('2022-08', 'M'),
#   'import_risk': 2.3924654519764452},
#  'Southern Europe.2022-08': {'place': 'Southern Europe',
#   'year-month': Period('2022-08', 'M'),
#   'import_risk': 5.5579624998482355},
#  'Western Europe.2022-08': {'place': 'Western Europe',
#   'year-month': Period('2022-08', 'M'),
#   'import_risk': 10.179204234160334},
#  'Central Europe.2022-08': {'place': 'Central Europe',
#   'year-month': Period('2022-08', 'M'),
#   'import_risk': 0.054870068241071795},
#  'South America.2022-08': {'place': 'South America',
#   'year-month': Period('2022-08', 'M'),
#   'import_risk': 0.3035207677162912},
#  'North America.2022-09': {'place': 'North America',
#   'year-month': Period('2022-09', 'M'),
#   'import_risk': 1.049869297108686},
#  'Southern Europe.2022-09': {'place': 'Southern Europe',
#   'year-month': Period('2022-09', 'M'),
#   'import_risk': 2.2755815064731437},
#  'Western Europe.2022-09': {'place': 'Western Europe',
#   'year-month': Period('2022-09', 'M'),
#   'import_risk': 4.199510826279802},
#  'Central Europe.2022-09': {'place': 'Central Europe',
#   'year-month': Period('2022-09', 'M'),
#   'import_risk': 0.018727381071537555},
#  'South America.2022-09': {'place': 'South America',
#   'year-month': Period('2022-09', 'M'),
#   'import_risk': 0.1760573408662057},
#  'North America.2022-10': {'place': 'North America',
#   'year-month': Period('2022-10', 'M'),
#   'import_risk': 0.5693024050248434},
#  'Southern Europe.2022-10': {'place': 'Southern Europe',
#   'year-month': Period('2022-10', 'M'),
#   'import_risk': 0.7185820178549536},
#  'Western Europe.2022-10': {'place': 'Western Europe',
#   'year-month': Period('2022-10', 'M'),
#   'import_risk': 1.41063129612537},
#  'Central Europe.2022-10': {'place': 'Central Europe',
#   'year-month': Period('2022-10', 'M'),
#   'import_risk': 0.0048298129766593855},
#  'South America.2022-10': {'place': 'South America',
#   'year-month': Period('2022-10', 'M'),
#   'import_risk': 0.07163861215909978},
#  'North America.2022-11': {'place': 'North America',
#   'year-month': Period('2022-11', 'M'),
#   'import_risk': 0.20739359483271275},
#  'Southern Europe.2022-11': {'place': 'Southern Europe',
#   'year-month': Period('2022-11', 'M'),
#   'import_risk': 0.18126032827881133},
#  'Western Europe.2022-11': {'place': 'Western Europe',
#   'year-month': Period('2022-11', 'M'),
#   'import_risk': 0.5279323704861174},
#  'Central Europe.2022-11': {'place': 'Central Europe',
#   'year-month': Period('2022-11', 'M'),
#   'import_risk': 0.0014937493920879322},
#  'South America.2022-11': {'place': 'South America',
#   'year-month': Period('2022-11', 'M'),
#   'import_risk': 0.029716890573098793},
#  'North America.2022-12': {'place': 'North America',
#   'year-month': Period('2022-12', 'M'),
#   'import_risk': 0.12208507685021172},
#  'Southern Europe.2022-12': {'place': 'Southern Europe',
#   'year-month': Period('2022-12', 'M'),
#   'import_risk': 0.09390927551674245},
#  'Western Europe.2022-12': {'place': 'Western Europe',
#   'year-month': Period('2022-12', 'M'),
#   'import_risk': 0.5237006305513223},
#  'Central Europe.2022-12': {'place': 'Central Europe',
#   'year-month': Period('2022-12', 'M'),
#   'import_risk': 0.001211752600043559},
#  'South America.2022-12': {'place': 'South America',
#   'year-month': Period('2022-12', 'M'),
#   'import_risk': 0.026333819126175308}}

# %%
"""this will generate a multi-index dataframe from the migrations dictionary"""
import_df = pd.DataFrame.from_dict({(i): import_dict[i] 
                       for i in import_dict.keys()}, orient='index')

import_df.reset_index(inplace=True)
#migrations_df.rename(columns={'level_0': 'tree_number', 'level_1': 'migration_event_number'}, inplace=True)

import_df
# Out:
#                       index            place year-month  import_risk
# 0     North America.2022-04    North America    2022-04     0.000000
# 1   Southern Europe.2022-04  Southern Europe    2022-04     0.000000
# 2    Western Europe.2022-04   Western Europe    2022-04     0.000000
# 3    Central Europe.2022-04   Central Europe    2022-04     0.000000
# 4     South America.2022-04    South America    2022-04     0.000000
# 5     North America.2022-05    North America    2022-05     0.081573
# 6   Southern Europe.2022-05  Southern Europe    2022-05     0.249455
# 7    Western Europe.2022-05   Western Europe    2022-05     0.415544
# 8    Central Europe.2022-05   Central Europe    2022-05     0.002354
# 9     South America.2022-05    South America    2022-05     0.005387
# 10    North America.2022-06    North America    2022-06     0.689119
# 11  Southern Europe.2022-06  Southern Europe    2022-06     1.773727
# 12   Western Europe.2022-06   Western Europe    2022-06     3.226134
# 13   Central Europe.2022-06   Central Europe    2022-06     0.017731
# 14    South America.2022-06    South America    2022-06     0.051759
# 15    North America.2022-07    North America    2022-07     2.670193
# 16  Southern Europe.2022-07  Southern Europe    2022-07     5.432430
# 17   Western Europe.2022-07   Western Europe    2022-07     9.791414
# 18   Central Europe.2022-07   Central Europe    2022-07     0.060053
# 19    South America.2022-07    South America    2022-07     0.196869
# 20    North America.2022-08    North America    2022-08     2.392465
# 21  Southern Europe.2022-08  Southern Europe    2022-08     5.557962
# 22   Western Europe.2022-08   Western Europe    2022-08    10.179204
# 23   Central Europe.2022-08   Central Europe    2022-08     0.054870
# 24    South America.2022-08    South America    2022-08     0.303521
# 25    North America.2022-09    North America    2022-09     1.049869
# 26  Southern Europe.2022-09  Southern Europe    2022-09     2.275582
# 27   Western Europe.2022-09   Western Europe    2022-09     4.199511
# 28   Central Europe.2022-09   Central Europe    2022-09     0.018727
# 29    South America.2022-09    South America    2022-09     0.176057
# 30    North America.2022-10    North America    2022-10     0.569302
# 31  Southern Europe.2022-10  Southern Europe    2022-10     0.718582
# 32   Western Europe.2022-10   Western Europe    2022-10     1.410631
# 33   Central Europe.2022-10   Central Europe    2022-10     0.004830
# 34    South America.2022-10    South America    2022-10     0.071639
# 35    North America.2022-11    North America    2022-11     0.207394
# 36  Southern Europe.2022-11  Southern Europe    2022-11     0.181260
# 37   Western Europe.2022-11   Western Europe    2022-11     0.527932
# 38   Central Europe.2022-11   Central Europe    2022-11     0.001494
# 39    South America.2022-11    South America    2022-11     0.029717
# 40    North America.2022-12    North America    2022-12     0.122085
# 41  Southern Europe.2022-12  Southern Europe    2022-12     0.093909
# 42   Western Europe.2022-12   Western Europe    2022-12     0.523701
# 43   Central Europe.2022-12   Central Europe    2022-12     0.001212
# 44    South America.2022-12    South America    2022-12     0.026334

# %%
import_df["year-month"] = import_df["year-month"].dt.to_timestamp()

# %%
alt.Chart(import_df).mark_line().encode(
    alt.X("year-month:T",axis=alt.Axis(title=None, grid=False, format="%B %Y")),
    alt.Y("import_risk"), 
    alt.Color("place:N"))
# Out:
# alt.Chart(...)

# %%
import_df.to_csv("estimated_importation_intensity_region.csv")
