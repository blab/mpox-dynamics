# %%
#preparing new cases from My world in Data for mpox in subsampled countries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/mparedes/Downloads/owid-monkeypox-data.csv") # from https://ourworldindata.org/explorers/monkeypox

# %%
df
# Out:
#       location  iso_code        date  total_cases  total_deaths  new_cases  \
# 0      Andorra       AND  2022-07-25          2.0           0.0        2.0
# 1      Andorra       AND  2022-07-26          3.0           0.0        1.0
# 2      Andorra       AND  2022-07-27          3.0           0.0        0.0
# 3      Andorra       AND  2022-07-28          3.0           0.0        0.0
# 4      Andorra       AND  2022-07-29          3.0           0.0        0.0
# ...        ...       ...         ...          ...           ...        ...
# 17413    World  OWID_WRL  2022-12-19      83038.0          67.0      144.0
# 17414    World  OWID_WRL  2022-12-20      83175.0          67.0      137.0
# 17415    World  OWID_WRL  2022-12-21      83339.0          72.0      164.0
# 17416    World  OWID_WRL  2022-12-22      83420.0          72.0       81.0
# 17417    World  OWID_WRL  2022-12-23      83497.0          72.0       77.0
#
#        new_deaths  new_cases_smoothed  new_deaths_smoothed  \
# ...

# %%
#the only countries with enough sequences (>5)
countries = ["Austria",
"Belgium",
"Canada",
"Colombia",
"France",
"Germany",
"Italy",
"Peru",
"Portugal",
"Slovakia",
"Slovenia",
"Spain",
"Switzerland",
"United States",
"United Kingdom",
]

# %%
df = df[df.location.isin(countries)]
df = df[["location", "date", "new_cases_smoothed"]]
df
# Out:
#             location        date  new_cases_smoothed
# 679          Austria  2022-05-23                0.14
# 680          Austria  2022-05-24                0.14
# 681          Austria  2022-05-25                0.14
# 682          Austria  2022-05-26                0.14
# 683          Austria  2022-05-27                0.14
# ...              ...         ...                 ...
# 16821  United States  2022-12-19                0.00
# 16822  United States  2022-12-20                0.00
# 16823  United States  2022-12-21                2.14
# 16824  United States  2022-12-22                2.14
# 16825  United States  2022-12-23                4.14
#
# [3099 rows x 3 columns]

# %%
#wide format for easy beauti input
wide_df = pd.pivot(df, index="location", columns="date", values="new_cases_smoothed")
wide_df = wide_df.replace(np.nan, 0.001)
wide_df = wide_df.replace(0.00, 0.001) #can't have 0 values for log standarization
wide_df
# Out:
# date            2022-05-07  2022-05-08  2022-05-09  2022-05-10  2022-05-11  \
# location
# Austria              0.001       0.001       0.001       0.001       0.001
# Belgium              0.001       0.001       0.001       0.001       0.001
# Canada               0.001       0.001       0.001       0.001       0.001
# Colombia             0.001       0.001       0.001       0.001       0.001
# France               0.001       0.001       0.001       0.001       0.001
# Germany              0.001       0.001       0.001       0.001       0.001
# Italy                0.001       0.001       0.001       0.001       0.001
# Peru                 0.001       0.001       0.001       0.001       0.001
# Portugal             0.001       0.001       0.001       0.001       0.001
# Slovakia             0.001       0.001       0.001       0.001       0.001
# Slovenia             0.001       0.001       0.001       0.001       0.001
# ...

# %%
rev_wide = wide_df[wide_df.columns[::-1]]

# %%
x = list(range(0,231,1))
rev_wide.columns = x

# %%
rev_wide = rev_wide.rename({"United States":"USA","United Kingdom":"UnitedKingdom"}, axis='rows')

# %%
rev_wide
# Out:
#                  0      1      2       3      4      5      6      7      8    \
# location
# Austria        0.001  0.001  0.001   0.001  0.001  0.001  0.001  0.001  0.001
#