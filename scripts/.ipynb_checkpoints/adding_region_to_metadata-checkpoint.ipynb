# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../monkeypox-build/data/nextstrain__metadata_random_300.tsv", sep = "\t")

# %%
df
# Out:
#                                     strain        date date_submitted  \
# 0                                  9000351  2022-08-01     2022-09-12
# 1                                  9000377  2022-08-01     2022-09-27
# 2                                  9000405  2022-09-01     2022-09-27
# 3                                  9000407  2022-09-30     2022-09-27
# 4                                  9000417  2022-08-31     2022-09-27
# ..                                     ...         ...            ...
# 296                MPXV22/human/USA-OK-277  2022-09-07     2022-10-17
# 297                   MPXV_USA_2022_TX0018  2022-06-29     2022-09-16
# 298                   MPXV_USA_2022_GA0012  2022-07-01     2022-09-16
# 299   MPX/Human/USA/CA-LACPHL-MA00237/2022  2022-07-20     2022-10-27
# 300  hMPX/Human/USA/CA-LACPHL-MA00052/2022  2022-07-25     2022-09-15
#
#             region clade_membership recency lineage          host  \
# 0           Europe              IIb   Older   B.1.7  Homo sapiens
# 1           Europe              IIb   Older   B.1.3  Homo sapiens
# 2           Europe              IIb   Older     B.1  Homo sapiens
# 3           Europe              IIb   Older   B.1.7  Homo sapiens
# 4           Europe              IIb   Older   B.1.2  Homo sapiens
# ..             ...              ...     ...     ...           ...
# 296  North America              IIb   Older   B.1.2  Homo sapiens
# 297  North America              IIb   Older   B.1.2  Homo sapiens
# 298  North America              IIb   Older   B.1.2  Homo sapiens
# 299  North America              IIb   Older   B.1.2  Homo sapiens
# 300  North America              IIb   Older   B.1.2  Homo sapiens
#
#             country                                             author  \
# 0    United Kingdom  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# 1    United Kingdom  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# 2    United Kingdom  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# 3    United Kingdom  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# 4    United Kingdom  Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# ..              ...                                                ...
# 296             USA  Chapman,R.C., Bernhard,K., McCutchen,E.L., Fau...
# 297             USA  Gigante,C.M., Kubin,G., Zhao,H., Batra,D., Het...
# 298             USA  Gigante,C.M., Pavlick,J., Zhao,H., Batra,D., H...
# 299             USA          Hemarajata,P., Green,N.M., Garrigues,J.M.
# 300             USA                          Hemarajata,P., Green,N.M.
#
#     accession  dinuc_context_fraction  GA_CT_fraction
# 0    OP413716                     1.0             1.0
# 1    OP536757                     NaN             NaN
# 2    OP536781                     1.0             1.0
# 3    OP536783                     1.0             1.0
# 4    OP536791                     1.0             1.0
# ..        ...                     ...             ...
# 296  OP650032                     1.0             1.0
# 297  OP450991                     NaN             NaN
# 298  OP451006                     NaN             NaN
# 299  OP722496                     NaN             NaN
# 300  OP440543                     NaN             NaN
#
# [301 rows x 13 columns]

# %%
north_america = ['Canada','USA']
western_europe = ['Austria','Germany','Switzerland','United Kingdom','France','Belgium']
central_europe = ['Slovakia','Slovenia']
southern_europe = ['Italy','Portugal','Spain']
south_american = ['Colombia','Peru']

# %%
df["region_coarse"] = np.nan
df.region_coarse[df.country.isin(north_america)] = "North America"
df['region_coarse'][df.country.isin(western_europe)] = "Western Europe"
df['region_coarse'][df.country.isin(central_europe)] = "Central Europe"
df['region_coarse'][df.country.isin(southern_europe)] = "Southern Europe"
df['region_coarse'][df.country.isin(south_american)] = "South America"
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_5166/557305204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.region_coarse[df.country.isin(north_america)] = "North America"

# %%
df = df[["accession", "date", "region_coarse", "country", "strain"]]
df
# Out:
#     accession        date   region_coarse         country  \
# 0    OP413716  2022-08-01  Western Europe  United Kingdom
# 1    OP536757  2022-08-01  Western Europe  United Kingdom
# 2    OP536781  2022-09-01  Western Europe  United Kingdom
# 3    OP536783  2022-09-30  Western Europe  United Kingdom
# 4    OP536791  2022-08-31  Western Europe  United Kingdom
# ..        ...         ...             ...             ...
# 296  OP650032  2022-09-07   North America             USA
# 297  OP450991  2022-06-29   North America             USA
# 298  OP451006  2022-07-01   North America             USA
# 299  OP722496  2022-07-20   North America             USA
# 300  OP440543  2022-07-25   North America             USA
#
#                                     strain
# 0                                  9000351
# 1                                  9000377
# 2                                  9000405
# 3                                  9000407
# 4                                  9000417
# ..                                     ...
# 296                MPXV22/human/USA-OK-277
# 297                   MPXV_USA_2022_TX0018
# 298                   MPXV_USA_2022_GA0012
# 299   MPX/Human/USA/CA-LACPHL-MA00237/2022
# 300  hMPX/Human/USA/CA-LACPHL-MA00052/2022
#
# [301 rows x 5 columns]

# %%
df.to_csv("../monkeypox-build/data/metadata_region_300_random.tsv", sep = "\t")
