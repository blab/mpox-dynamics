# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../monkeypox-build/results/hmpxv1/metadata.tsv", sep = "\t")

# %%
df
# Out:
#        strain accession genbank_accession_rev        strain_original  \
# 0    ON676708  ON676708            ON676708.1       MPXV_USA_2021_MD
# 1    ON568298  ON568298            ON568298.1       MPXV-BY-IMB25241
# 2    ON843165  ON843165            ON843165.1  Monkeypox/PT0033/2022
# 3    ON585034  ON585034            ON585034.1  Monkeypox/PT0007/2022
# 4    OP414374  OP414374            OP414374.1  Monkeypox/PT0345/2022
# ..        ...       ...                   ...                    ...
# 306  OX297403  OX297403            OX297403.1                    RNA
# 307  OX336038  OX336038            OX336038.1                    RNA
# 308  OX291694  OX291694            OX291694.1                    RNA
# 309  OX291676  OX291676            OX291676.1                    RNA
# 310  OX336004  OX336004            OX336004.1                    RNA
#
#            date         region   country  division location          host  \
# 0    2021-11-XX  North America       USA  Maryland      NaN  Homo sapiens
# 1    2022-05-19         Europe   Germany       NaN      NaN  Homo sapiens
# 2    2022-05-24         Europe  Portugal       NaN      NaN  Homo sapiens
# 3    2022-05-15         Europe  Portugal       NaN      NaN  Homo sapiens
# 4    2022-05-26         Europe  Portugal       NaN      NaN  Homo sapiens
# ..          ...            ...       ...       ...      ...           ...
# 306  2022-08-09         Europe  Slovakia       NaN      NaN  Homo sapiens
# 307  2022-08-31         Europe  Slovakia       NaN      NaN  Homo sapiens
# 308  2022-08-01         Europe  Slovakia       NaN      NaN  Homo sapiens
# 309  2022-08-01         Europe  Slovakia       NaN      NaN  Homo sapiens
# 310  2022-08-26         Europe  Slovakia       NaN      NaN  Homo sapiens
#
#      ... nonACGTN QC_missing_data QC_mixed_sites  QC_rare_mutations  \
# 0    ...      0.0            good           good               good
# 1    ...      0.0            good           good               good
# 2    ...      0.0            good           good               good
# 3    ...      0.0            good           good               good
# 4    ...      0.0            good           good               good
# ..   ...      ...             ...            ...                ...
# 306  ...      1.0            good           good               good
# 307  ...      1.0            good           good               good
# 308  ...      1.0            good           good               good
# 309  ...      1.0            good           good               good
# 310  ...      1.0            good           good               good
#
#     QC_frame_shifts QC_stop_codons    frame_shifts  is_reverse_complement  \
# 0              good           good             NaN                  False
# 1              good           good             NaN                  False
# 2              good           good             NaN                  False
# 3              good           good             NaN                  False
# 4              good           good             NaN                  False
# ..              ...            ...             ...                    ...
# 306            good           good             NaN                  False
# 307            good           good             NaN                  False
# 308            good           good             NaN                  False
# 309            good           good  OPG044:146-150                  False
# 310            good           good             NaN                  False
#
#                                                authors  \
# 0    Gigante,C.M., Myers,R., Seabolt,M.H., Wilkins,...
# 1    Antwerpen,M.H., Lang,D., Zange,S., Walter,M.C....
# 2    Isidro,J., Borges,V., Pinto,M., Sobral,D., San...
# 3    Isidro,J., Borges,V., Pinto,M., Ferreira,R., S...
# 4    Isidro,J., Borges,V., Pinto,M., Sobral,D., San...
# ..                                                 ...
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
#
#                                            institution
# 0    Division of High-Consequence Pathogens & Patho...
# 1    Microbiol Genomics & Bioinformatics, Bundesweh...
# 2                                                  NaN
# 3    Institute National de Saude Doutor Ricardo Jor...
# 4    National Institute of Health Doutor Ricardo Jo...
# ..                                                 ...
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
#
# [311 rows x 30 columns]

# %%
north_america = ['Canada','USA']
western_europe = ['Austria','Germany','Switzerland','United Kingdom','France','Belgium']
central_europe = ['Slovakia','Slovenia']
southern_europe = ['Italy','Portugal','Spain']
south_american = ['Colombia','Peru']

# %%
df["region_coarse"] = np.nan
df.region_coarse[df.country.isin(north_america)] = "North America"
df['region_coarse'][df.country.isin(western_europe)] = "Western Europe"
df['region_coarse'][df.country.isin(central_europe)] = "Central Europe"
df['region_coarse'][df.country.isin(southern_europe)] = "Southern Europe"
df['region_coarse'][df.country.isin(south_american)] = "South America"
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_90498/557305204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.region_coarse[df.country.isin(north_america)] = "North America"

# %%
df = df[["accession", "date", "region_coarse", "country", "strain_original"]]
df
# Out:
#     accession        date    region_coarse   country    strain
# 0    ON676708  2021-11-XX    North America       USA  ON676708
# 1    ON568298  2022-05-19   Western Europe   Germany  ON568298
# 2    ON843165  2022-05-24  Southern Europe  Portugal  ON843165
# 3    ON585034  2022-05-15  Southern Europe  Portugal  ON585034
# 4    OP414374  2022-05-26  Southern Europe  Portugal  OP414374
# ..        ...         ...              ...       ...       ...
# 306  OX297403  2022-08-09   Central Europe  Slovakia  OX297403
# 307  OX336038  2022-08-31   Central Europe  Slovakia  OX336038
# 308  OX291694  2022-08-01   Central Europe  Slovakia  OX291694
# 309  OX291676  2022-08-01   Central Europe  Slovakia  OX291676
# 310  OX336004  2022-08-26   Central Europe  Slovakia  OX336004
#
# [311 rows x 5 columns]

# %%
df.to_csv("../monkeypox-build/data/metadata_region_300_HQ.tsv", sep = "\t")
