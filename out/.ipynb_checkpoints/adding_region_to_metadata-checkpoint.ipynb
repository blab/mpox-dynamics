# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../monkeypox-build/data/nextstrain__metadata_2.tsv", sep = "\t")

# %%
df
# Out:
#                                     strain accession        date  \
# 0                                     4061  ON838940  2022-05-20
# 1                                     8887  ON838939  2022-06-06
# 2                                  9000353  OP413717  2022-08-01
# 3                                  9000370  OP536751  2022-08-01
# 4                                  9000374  OP536754  2022-08-01
# ..                                     ...       ...         ...
# 555  MPXV/Human/USA/CA-LACPHL-MA00303/2022  OP890537  2022-09-29
# 556                               B1221120  OP935997  2022-11-09
# 557                               B1221119  OP935996  2022-11-08
# 558  MPXV/Human/USA/CA-LACPHL-MA00288/2022  OP890546  2022-10-04
# 559  MPXV/Human/USA/CA-LACPHL-MA00290/2022  OP890548  2022-10-02
#
#     date_submitted clade_membership         region          host  \
# 0       2022-06-24              IIb         Europe  Homo sapiens
# 1       2022-06-24              IIb         Europe  Homo sapiens
# 2       2022-09-12              IIb         Europe  Homo sapiens
# 3       2022-09-27              IIb         Europe  Homo sapiens
# 4       2022-09-27              IIb         Europe  Homo sapiens
# ..             ...              ...            ...           ...
# 555     2022-11-24              IIb  North America  Homo sapiens
# 556     2022-12-02              IIb  North America  Homo sapiens
# 557     2022-12-02              IIb  North America  Homo sapiens
# 558     2022-11-24              IIb  North America  Homo sapiens
# 559     2022-11-24              IIb  North America  Homo sapiens
#
#             country        recency lineage  \
# 0             Spain          Older     B.1
# 1             Spain          Older     B.1
# 2    United Kingdom          Older     B.1
# 3    United Kingdom          Older   B.1.3
# 4    United Kingdom          Older     B.1
# ..              ...            ...     ...
# 555             USA          Older   B.1.2
# 556             USA  One month ago   B.1.2
# 557             USA  One month ago   B.1.2
# 558             USA          Older   B.1.2
# 559             USA          Older   B.1.2
#
#                                                 author  \
# 0    de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...
# 1    de la Hoz-Sanchez,B., Lopez-Ortiz,M., Gutierre...
# 2    Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# 3    Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# 4    Groves,N., Osman,K.L., Lewandowski,K.S., Carte...
# ..                                                 ...
# 555          Hemarajata,P., Green,N.M., Garrigues,J.M.
# 556                              Bajwa,M.I., Miller,H.
# 557                              Bajwa,M.I., Miller,H.
# 558          Hemarajata,P., Green,N.M., Garrigues,J.M.
# 559          Hemarajata,P., Green,N.M., Garrigues,J.M.
#
#      dinuc_context_fraction  GA_CT_fraction
# 0                       NaN             NaN
# 1                       1.0             1.0
# 2                       NaN             NaN
# 3                       1.0             1.0
# 4                       1.0             1.0
# ..                      ...             ...
# 555                     1.0             1.0
# 556                     NaN             NaN
# 557                     1.0             1.0
# 558                     NaN             NaN
# 559                     NaN             NaN
#
# [560 rows x 13 columns]

# %%
north_america = ['Canada','USA']
western_europe = ['Austria','Germany','Switzerland','United Kingdom','France','Belgium']
central_europe = ['Slovakia','Slovenia']
southern_europe = ['Italy','Portugal','Spain']
south_american = ['Colombia','Peru']

# %%
df["region_coarse"] = np.nan
df.region_coarse[df.country.isin(north_america)] = "North America"
df['region_coarse'][df.country.isin(western_europe)] = "Western Europe"
df['region_coarse'][df.country.isin(central_europe)] = "Central Europe"
df['region_coarse'][df.country.isin(southern_europe)] = "Southern Europe"
df['region_coarse'][df.country.isin(south_american)] = "South America"
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_85716/557305204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.region_coarse[df.country.isin(north_america)] = "North America"

# %%
df = df[["accession", "date", "region_coarse", "strain"]]
df
# Out:
#     accession        date    region_coarse  \
# 0    ON838940  2022-05-20  Southern Europe
# 1    ON838939  2022-06-06  Southern Europe
# 2    OP413717  2022-08-01   Western Europe
# 3    OP536751  2022-08-01   Western Europe
# 4    OP536754  2022-08-01   Western Europe
# ..        ...         ...              ...
# 555  OP890537  2022-09-29    North America
# 556  OP935997  2022-11-09    North America
# 557  OP935996  2022-11-08    North America
# 558  OP890546  2022-10-04    North America
# 559  OP890548  2022-10-02    North America
#
#                                     strain
# 0                                     4061
# 1                                     8887
# 2                                  9000353
# 3                                  9000370
# 4                                  9000374
# ..                                     ...
# 555  MPXV/Human/USA/CA-LACPHL-MA00303/2022
# 556                               B1221120
# 557                               B1221119
# 558  MPXV/Human/USA/CA-LACPHL-MA00288/2022
# 559  MPXV/Human/USA/CA-LACPHL-MA00290/2022
#
# [560 rows x 4 columns]

# %%
df.to_csv("../monkeypox-build/data/metadata_region.tsv", sep = "\t")
